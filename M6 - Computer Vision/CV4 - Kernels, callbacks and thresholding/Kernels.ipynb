# %% [markdown]
# # Computer Vision Kernels

# %% [markdown]
# ## Import Statements

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('img/night1.jpg')
img2 = cv2.imread('img/bridge.jpg')
img3 = cv2.imread('img/beach.jpg')

def imshow(img):
    plt.figure(figsize = (10,7));
    plt.imshow(img[:,:,::-1]);
    # plt.imshow(img)

# rgb_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
# resize images
# img_sm = cv2.resize(img, (780, 540), interpolation = cv2.INTER_NEAREST)
# img_sm = cv2.resize(img, (0, 0), fx = 0.1, fy = 0.1)
# img2_sm = cv2.resize(img2, (0, 0), fx = 0.1, fy = 0.1)
# img3_sm = cv2.resize(img3, (0, 0), fx = 0.1, fy = 0.1)

# %%
imshow(img)

# %% [markdown]
# ## Blur

# %%
# Load one or more images to practive with

# %%
# Create a blur kernel with numpy of size (3,3)
blur_kernel = np.ones((3,3), np.float32)/3

# %% [markdown]
# [Hint](# "All values should sum up to 1 with the highest value in the center of the kernel, all values are positive.")

# %%
# Create a copy of the imagre and apply the kernel to the image unsing cv2.filter2D and display the blurred image
blur_img = cv2.filter2D(img,-1, blur_kernel)

# %%
# Repeat the operations but with kernels of size (5,5) and (7,7) what is the difference?
blur_kernel_5 = np.ones((5,5), np.float32)/25
blur_kernel_7 = np.ones((7,7), np.float32)/49

# %%
# Create a new copy of the original image and apply a GaussianBlur
img_copy = img.copy()

# %% [markdown]
# [Hint](# "cv2.GaussianBlur")

# %%
# Experiment with cv2.blur
img_blur_2 = cv2.blur(img,(25,25))
imshow(img_blur_2)

# %%
# Experiment with cv2.medianBlur
median_blur = cv2.medianBlur(img,9)
imshow(median_blur)

# %%
# Experiment with cv2.bilateralFilter
gaussian_blur = cv2.GaussianBlur(img, (9,9), 0)
imshow(gaussian_blur)

# %% [markdown]
# ## Sharpening

# %%
# Create a 3 by 3 sharpening kernel with numpy
kernel = np.array([[-1, -1, -1],
                   [-1, 9, -1],
                   [-1, -1, -1]])

# %% [markdown]
# [Hint](# "All values should sum up to 1 with the highest value in the center of the kernel.")

# %%
# Create a copy of the image and apply the kernel to the image using cv2.filter2D and display the filtered image
img_sharp = cv2.filter2D(img_2w_k, -1, kernel)
imshow(img_sharp)

# %% [markdown]
# ## Edge detection

# %%
# Create a 3 by 3 kernel with numpy to detect edges

edges = cv2.Canny(img,100,200)
plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# [Hint](# "All values should sum up to 0 with the highest value in the center of the kernel.")

# %%
# Create a copy of the imagre and apply the kernel to the image unsing cv2.filter2D and display the filtered image

# %%
# Use cv2.Sobel to detect edges in the x orientation

# Gradient-X
grad_x = cv.Sobel(img, ddepth, 1, 0, ksize=3, scale=scale, delta=delta, borderType=cv.BORDER_DEFAULT)

abs_grad_x = cv.convertScaleAbs(grad_x)

# %%
# Use cv2.Sobel to detect edges in the y orientation

# Gradient-Y
grad_y = cv.Sobel(img, ddepth, 0, 1, ksize=3, scale=scale, delta=delta, borderType=cv.BORDER_DEFAULT)

abs_grad_y = cv.convertScaleAbs(grad_y)

# %%
# merge x and y
grad = cv.addWeighted(abs_grad_x, 0.5, abs_grad_y, 0.5, 0)

# %%
# Use cv2.Sobel and try to detect edges in the x and y orientation

# %%
# Use cv2.Canny to detect edges
canny = cv2.Canny(img,100,200)
plt.figure(figsize=(15,10));
plt.imshow(canny, cmap='gray')
