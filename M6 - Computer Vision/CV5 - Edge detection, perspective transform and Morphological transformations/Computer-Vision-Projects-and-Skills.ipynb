# %% [markdown]
# # Computer Vision

# %% [markdown]
# ### List your new Computer Vision skills, usages and importance

# %% [markdown]
# ### Skills learned on Computer Vision
#
# - create poligons and circles over images
# - write on images
# - open webcam
# - Clean images (remove noise)
# - Resize / crop images
# - Apply filters in images and videos
#     - black and white
#     - different colors
#     - blur
#     - sharp
#     - opacity
#     - invert images
# - creating green screen
# - keyboard callbacks
# - mouse callbacks
#
# ### Use cases of Computer Vision
#
# - identify objects
# - image manipulation
# - extract information on images

# %% [markdown]
# ### List your projects with repository url

# %% [markdown]
# ### Photo Filter
# Project description: Change image style
# Computer vision skills applied:
# - imread
# - cvtColor
# - split
# - merge
# - add
# - addWeighted
# - filter2D
# Repository url: [Photo Filter](https://github.com/fistadev/AISpring21/tree/main/M6%20-%20Computer%20Vision/CV_projects/photo%20filter%20app)
#
# #
#
# ### Sketches
# Project description: Apply image outlines
# Computer vision skills applied :
# - imread
# - cvtColor
# - threshold
# - Canny
# Repository url: [Sketches](https://github.com/fistadev/AISpring21/tree/main/M6%20-%20Computer%20Vision/CV_projects/sketch)
#
# #
#
# ### Green Screen
# Project description: Apply image outlines
# Computer vision skills applied :
# - imread
# - cvtColor
# - np.array
# - inRange
# - np.copy
# Repository url: [Green Screen](https://github.com/fistadev/AISpring21/blob/main/M6%20-%20Computer%20Vision/CV_projects/green_screen.py)

# %% [markdown]
# ### Anything else you would like to add or share?
