# %%
import cv2
import matplotlib.pyplot as plt

# %%
cv2.__version__
# Out:
# '4.5.1'

# %%
# img = cv2.imread('img/bird.jpg')
# img2 = cv2.imread('img/bokeh.jpg')
img3 = cv2.imread('annotations.jpg')

# %%
img3
# Out:
# array([[[ 50,  56,  55],
#         [ 52,  58,  57],
#         [ 54,  60,  59],
#         ...,
#         [ 35,  95, 137],
#         [ 27,  54,  91],
#         [ 56,  68,  62]],
#
#        [[ 51,  57,  56],
#         [ 52,  58,  57],
#         [ 54,  60,  59],
#         ...,
#         [ 28,  80, 120],
#         [ 32,  53,  85],
#         [ 55,  63,  56]],
#
#        [[ 51,  57,  56],
#         [ 52,  58,  57],
#         [ 54,  60,  59],
#         ...,
#         [ 14,  56,  91],
#         [ 44,  57,  83],
#         [ 56,  57,  47]],
#
#        ...,
#
#        [[177, 166, 158],
#         [182, 171, 163],
#         [183, 172, 164],
#         ...,
#         [ 61,  63,  74],
#         [ 40,  42,  53],
#         [ 48,  50,  60]],
#
#        [[179, 168, 160],
#         [181, 170, 162],
#         [178, 167, 159],
#         ...,
#         [ 61,  62,  76],
#         [ 37,  39,  50],
#         [ 49,  51,  61]],
#
#        [[181, 171, 161],
#         [178, 168, 158],
#         [172, 162, 152],
# ...

# %%
# grayscale_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
# grayscale_img
# Out:
# array([[102, 100,  99, ...,  85,  87,  81],
#        [101,  98, 104, ...,  79,  84,  88],
#        [101, 104, 103, ...,  81,  84,  85],
#        ...,
#        [162, 165, 164, ..., 152, 154, 154],
#        [162, 165, 163, ..., 151, 154, 154],
#        [161, 163, 162, ..., 152, 155, 155]], dtype=uint8)

# %%
type(img3)
# Out:
# numpy.ndarray

# %%
cv2.imshow('My image', img3)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# -1

# %%
# Out:
# -1

# %%
plt.figure(figsize=(10, ))
plt.imshow(img3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-f8d9f606370c> in <module>
# ----> 1 plt.figure(figsize=(10, ))
#       2 plt.imshow(img2)
#
# /opt/anaconda3/envs/machine_learning/lib/python3.8/site-packages/matplotlib/pyplot.py in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     685             dpi = 72
#     686
# --> 687         figManager = new_figure_manager(num, figsize=figsize,
#     688                                         dpi=dpi,
#     689                                         facecolor=facecolor,
#
# /opt/anaconda3/envs/machine_learning/lib/python3.8/site-packages/matplotlib/pyplot.py in new_figure_manager(*args, **kwargs)
#     313     """Create a new figure manager instance."""
#     314     _warn_if_gui_out_of_main_thread()
# --> 315     return _backend_mod.new_figure_manager(*args, **kwargs)
# ...

# %%
# plt.figure(figsize=(10,5))
# plt.imshow(grayscale_img, cmap="gray")

# %%
rgb_img = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

# %%
cropped_img = rgb_img[600:1100, 450:1150]

# %%
plt.figure(figsize=(10,5))
plt.imshow(cropped_img)

# %%
crop2 = cv2.imread('img_cropped/bird_cropped_1.jpg')

# %%
plt.figure(figsize=(10,5))
plt.imshow(crop2)

# %%
# save new file
cv2.imwrite('img_cropped/bird_cropped_1.jpg', cropped_img)
# Out:
# True

# %%
# !ls
# Out:
# bird_cropped.jpg   img                start_opencv.ipynb
# bird_cropped_1.jpg img_cropped

# %%
cvs.putText(clone_img, 'Hello', (650,650), )
